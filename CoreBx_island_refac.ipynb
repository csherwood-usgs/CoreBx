# %% [markdown]
# ### CoreBx_island_refac - Interpolate the North Core Banks DEMs onto rotated 1-m grid and save each as a .nc file.
#
# Versioning jumped from v6 to refac
#
# New invV5
# * Files are switched to the "merged DEMs" that Jin-Si made, so the rapid iteration can occur.
# * Box is re-adjusted to accomodate the whole island. The resulting array is huge, but manageble.
#
# New in v2
# * Now 4D maps, two made made during visit to Santa Cruz and two ftp'd from Andy
# * Apr. 9 - changed to _v3 for Sep map
# * Now does the interpolation without the loop
# * Apr. 21 - moved origin to SE to accomodate curvature in NE end of island. Add 400 m to size of array.
# * Watch file names, esp. underline (or not) after "1m_DEM"
#
# New in v6
# * Added maps through Sep 28 2020
#
# New in refac
# * Added newest DEMs, but they have not been clipped.
# * Code is now maintained in ../src/CoreBx, so paths to output files has been added.
# * Changed exent of interpolation grid to fit inside bbox of raster arrays
# * Moved make_grid to CoreBx_funcs
# * Switched names for alongshore and offshore
# * Switched to nearest-neighbor interpolation
#
# New in April, 2022
# * First four maps are clipped

# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import rioxarray
# from dask.distributed import LocalCluster
from scipy import interpolate, signal
from CoreBx_funcs import *
# %matplotlib inline

# %%
# April 9, 2020: Replaced   "2019-09-12-13_1m_DEM_4D_crop.tif",\
# with _v3 and re-ran on my desktop

# May 4, 2020 - Changed to use Jin-Si's merged dems
# Dec 11, 2021 - Switched to unclipped candidate DEMs

#fdir = "C:/crs/proj/2019_DorianOBX/Santa_Cruz_Products/merged_dems/"
#fdir = "D:/crs/proj/2019_DorianOBX/Santa_Cruz_Products/clipped_dems/"

fin_dir = 'C:/crs/proj/2021_FloSupp_Release/clipfest/dems/'
clip_dir = 'C:/crs/proj/2021_FloSupp_Release/clipfest/dems/'
fnames0 = (\
#'20181006_Ocracoke_Inlet_to_Ophelia_Inlet_1m_UTM18N_NAVD88_adj_cog.tif',\
fin_dir+'20190830_Ocracoke_Inlet_to_Ophelia_Inlet_NAD83_2011_NAVD88_UTM18_1m_adj_cog.tif',\
#'20190908_Ocracoke_Inlet_to_Ophelia_Inlet_NAD83_2011_NAVD88_UTM18_1m_adj_cog.tif',\
fin_dir+'20190912-13_Ocracoke_Inlet_to_Ophelia_Inlet_NAD83_2011_NAVD88_UTM18_1m_adj_cog.tif',\
#'20190913_Ocracoke_Inlet_to_Ophelia_Inlet_NAD83_2011_NAVD88_UTM18_1m_adj_cog.tif',\
fin_dir+'20191011_Ocracoke_Inlet_to_Cape_Lookout_NAD83_2011_NAVD88_UTM18_1m_adj_cog.tif',\
fin_dir+'20191126_Ocracoke_Inlet_to_Cape_Lookout_NAD83_2011_NAVD88_UTM18_1m_adj_cog.tif')
fnames1 = (\
clip_dir+'20200208-9_Ocracoke_Inlet_to_Cape_Lookout_NAD83_2011_NAVD88_UTM18_1m_adj_cog.tif',\
clip_dir+'20200508-9_Ocracoke_Inlet_to_Cape_Lookout_NAD83_2011_NAVD88_UTM18_1m_adj_cog.tif',\
clip_dir+'20200802_Ocracoke_Inlet_to_Cape_LookoutNAD83_2011_NAVD88_UTM18_1m_adj_cog.tif',\
clip_dir+'20200805-8_Ocracoke_Inlet_to_Cape_LookoutNAD83_2011_NAVD88_UTM18_1m_adj_cog.tif',\
clip_dir+'20200928_Ocracoke_Inlet_to_Cape_LookoutNAD83_2011_NAVD88_UTM18_1m_adj_cog.tif',\
clip_dir+'20210430_Ocracoke_Inlet_to_Cape_LookoutNAD83_2011_NAVD88_UTM18_1m_adj_cog.tif')

fnames=np.append(fnames0,fnames1)

titles = ([\
#         "Oct 6 2018 post-Florence"\
         "Aug 30 2019 pre-Dorian",\
         "Sep 12-13 2019 post-Dorian",\
         "Oct 11 2019 lidar merge",\
         "Nov 26 2019 post-Nor'easter",\
         "Feb 8-9 2020",\
         "May 8-9 2020",\
         "Aug 2 2020 pre-Isaias",\
         "Aug 5- 2020 post-Isaias",\
         "Sep 28 2020 post-Teddy",\
         "May 30 2021"])

dates = ([\
         "2019-08-30",\
         "2019-09-12",\
         "2019-10-11",\
         "2019-11-26",\
         "2020-02-09",\
         "2020-04-09",\
         "2020-08-05",\
         "2020-08-09",\
         "2020-09-28",\
         "2021-05-30"])

nf = len(fnames)
nft = len(titles)
print('Length of datasets',nf,nft)

#TODO - Consider remaking this base file
fill_fnames = ('EBK_201909_YesLidar_Comb_Extent_m.tif')
fill_titles = ('Sep_fill')

# optional median-filter smoothing of original maps
smooth = False
# kernal size...this should be an odd number >= dxy/0.1
ksize = 3
# Out:
# ['C:/crs/proj/2021_FloSupp_Release/clipfest/dems/20190830_Ocracoke_Inlet_to_Ophelia_Inlet_NAD83_2011_NAVD88_UTM18_1m_adj_cog.tif'
#  'C:/crs/proj/2021_FloSupp_Release/clipfest/dems/20190912-13_Ocracoke_Inlet_to_Ophelia_Inlet_NAD83_2011_NAVD88_UTM18_1m_adj_cog.tif'
#  'C:/crs/proj/2021_FloSupp_Release/clipfest/dems/20191011_Ocracoke_Inlet_to_Cape_Lookout_NAD83_2011_NAVD88_UTM18_1m_adj_cog.tif'
#  'C:/crs/proj/2021_FloSupp_Release/clipfest/dems/20191126_Ocracoke_Inlet_to_Cape_Lookout_NAD83_2011_NAVD88_UTM18_1m_adj_cog.tif'
#  'C:/crs/proj/2021_FloSupp_Release/clipfest/dems/20200208-9_Ocracoke_Inlet_to_Cape_Lookout_NAD83_2011_NAVD88_UTM18_1m_adj_cog.tif'
#  'C:/crs/proj/2021_FloSupp_Release/clipfest/dems/20200508-9_Ocracoke_Inlet_to_Cape_Lookout_NAD83_2011_NAVD88_UTM18_1m_adj_cog.tif'
#  'C:/crs/proj/2021_FloSupp_Release/clipfest/dems/20200802_Ocracoke_Inlet_to_Cape_LookoutNAD83_2011_NAVD88_UTM18_1m_adj_cog.tif'
#  'C:/crs/proj/2021_FloSupp_Release/clipfest/dems/20200805-8_Ocracoke_Inlet_to_Cape_LookoutNAD83_2011_NAVD88_UTM18_1m_adj_cog.tif'
#  'C:/crs/proj/2021_FloSupp_Release/clipfest/dems/20200928_Ocracoke_Inlet_to_Cape_LookoutNAD83_2011_NAVD88_UTM18_1m_adj_cog.tif'
#  'C:/crs/proj/2021_FloSupp_Release/clipfest/dems/20210430_Ocracoke_Inlet_to_Cape_LookoutNAD83_2011_NAVD88_UTM18_1m_adj_cog.tif']
# Length of datasets 10 10

# %%
# Read in a dict to define the rotated coordinate system
r = yaml2dict('island_box.yml')
print(r)

# Make a grid 
xu,yu,xrot,yrot,xcoords,ycoords = make_grid(**r)

ny,nx = np.shape(xu)
print('Size of grid:',ny,nx)
# Out:
# {'name': 'ncorebx_refac', 'e0': 378490.0, 'n0': 3855740.0, 'xlen': 36500.0, 'ylen': 1500.0, 'dxdy': 1.0, 'theta': 42.0}
# make_grid: Shape of xrot, yrot:  (1500, 36500) (1500, 36500)
# corners x, corners y]
# [[ 378490.03700711 3855740.70613772]
#  [ 405614.07999221 3880163.30413921]
#  [ 404611.05321328 3881277.2782326 ]
#  [ 377487.01022818 3856854.68023111]
#  [ 378490.03700711 3855740.70613772]]
# Saving to ncorebx_refac.csv
# Size of grid: 1500 36500

# %%
# %%time
# output for rotated DEMs
dem_path ='C:/crs/proj/2019_DorianOBX/Dorian_paper_analyses/rotated_dems/'

dslist=[]
for i, fn in enumerate(fnames):
    iswarned = False
    fpath = fn
    print(i, fpath)

    # Old way: open the tif with XArray as a DataArray
    #     da = xr.open_rasterio(fpath)
    # New way: use rioxarray
    # The "masked" option puts in NaNs, but takes longer.
    da = rioxarray.open_rasterio( fpath, masked=True )

    print( np.shape(np.flipud(da['y'].values)), np.shape(da['x'].values), np.shape( np.flipud(da.values)) )
    x = da['x'].values
    y = np.flipud(da['y'].values)

    # Not sure how da.values got a singleton dimension, but squeeze gets rid of it.
    # However, make sure to squeeze before flipping
    z = np.flipud(np.squeeze(da.values))
    print(np.shape(x),np.shape(y),np.shape(z))

    if(smooth):
        # smooth with 2D running median
        zs = signal.medfilt2d(z, kernel_size=ksize)
    else:
        zs = z

    f = interpolate.RegularGridInterpolator( (y, x), zs, method='nearest')   

    # Array for interpolated elevations
    zi=np.NaN*np.ones((ny,nx))
        
    # this is the fast iteration, which only works when all of the source points fall inside the target box
    try:
        zi=f((yu,xu))

    # this is a slow iteration through all of the points, but allows us to skip ones that are outside
    except:
        if(not iswarned):
            print("Warning: using slow iteration.")
            iswarned = True
        for ij in np.ndindex(zi.shape):
            try:
                zi[ij]=f((yu[ij],xu[ij]))
            except:
                zi[ij]=np.NaN

    #dar = xr.DataArray(zi,dims=['Alongshore','Cross-shore'],coords={'Alongshore': ycoords, 'Cross-shore':xcoords })
    dar = xr.DataArray(zi,dims=['Cross-shore','Alongshore'],coords={'Cross-shore': ycoords, 'Alongshore' :xcoords })

    dar = dar.chunk()
    dslist.append(dar)

dsa = xr.concat(dslist, dim='map')
# Out:
# 0 C:/crs/proj/2021_FloSupp_Release/clipfest/dems/20190830_Ocracoke_Inlet_to_Ophelia_Inlet_NAD83_2011_NAVD88_UTM18_1m_adj_cog.tif
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# File <timed exec>:16, in <module>
#
# File ~\Anaconda3\envs\CRS\lib\site-packages\xarray\core\dataarray.py:646, in DataArray.values(self)
#     637 @property
#     638 def values(self) -> np.ndarray:
#     639     """
#     640     The array's data as a numpy.ndarray.
#     641
#    (...)
#     644     type does not support coercion like this (e.g. cupy).
#     645     """
# --> 646     return self.variable.values
#
# File ~\Anaconda3\envs\CRS\lib\site-packages\xarray\core\variable.py:519, in Variable.values(self)
#     516 @property
#     517 def values(self):
#     518     """The variable's data as a numpy.ndarray"""
# --> 519     return _as_array_or_item(self._data)
#
# File ~\Anaconda3\envs\CRS\lib\site-packages\xarray\core\variable.py:259, in _as_array_or_item(data)
#     245 def _as_array_or_item(data):
#     246     """Return the given values as a numpy array, or as an individual item if
#     247     it's a 0d datetime64 or timedelta64 array.
#     248
#    (...)
#     257     TODO: remove this (replace with np.asarray) once these issues are fixed
#     258     """
# --> 259     data = np.asarray(data)
#     260     if data.ndim == 0:
#     261         if data.dtype.kind == "M":
#
# File ~\Anaconda3\envs\CRS\lib\site-packages\xarray\core\indexing.py:551, in MemoryCachedArray.__array__(self, dtype)
#     550 def __array__(self, dtype=None):
# --> 551     self._ensure_cached()
#     552     return np.asarray(self.array, dtype=dtype)
#
# File ~\Anaconda3\envs\CRS\lib\site-packages\xarray\core\indexing.py:548, in MemoryCachedArray._ensure_cached(self)
#     546 def _ensure_cached(self):
#     547     if not isinstance(self.array, NumpyIndexingAdapter):
# --> 548         self.array = NumpyIndexingAdapter(np.asarray(self.array))
#
# File ~\Anaconda3\envs\CRS\lib\site-packages\xarray\core\indexing.py:521, in CopyOnWriteArray.__array__(self, dtype)
#     520 def __array__(self, dtype=None):
# --> 521     return np.asarray(self.array, dtype=dtype)
#
# File ~\Anaconda3\envs\CRS\lib\site-packages\xarray\core\indexing.py:422, in LazilyIndexedArray.__array__(self, dtype)
#     420 def __array__(self, dtype=None):
#     421     array = as_indexable(self.array)
# --> 422     return np.asarray(array[self.key], dtype=None)
#
# File ~\Anaconda3\envs\CRS\lib\site-packages\rioxarray\_io.py:301, in RasterioArrayWrapper.__getitem__(self, key)
#     300 def __getitem__(self, key):
# --> 301     return indexing.explicit_indexing_adapter(
#     302         key, self.shape, indexing.IndexingSupport.OUTER, self._getitem
#     303     )
#
# File ~\Anaconda3\envs\CRS\lib\site-packages\xarray\core\indexing.py:711, in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#     689 """Support explicit indexing by delegating to a raw indexing method.
#     690
#     691 Outer and/or vectorized indexers are supported by indexing a second time
#    (...)
#     708 Indexing result, in the form of a duck numpy-array.
#     709 """
#     710 raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# --> 711 result = raw_indexing_method(raw_key.tuple)
#     712 if numpy_indices.tuple:
#     713     # index the loaded np.ndarray
#     714     result = NumpyIndexingAdapter(np.asarray(result))[numpy_indices]
#
# File ~\Anaconda3\envs\CRS\lib\site-packages\rioxarray\_io.py:289, in RasterioArrayWrapper._getitem(self, key)
#     287 out = riods.read(band_key, window=window, masked=self.masked)
#     288 if self.masked:
# --> 289     out = np.ma.filled(out.astype(self.dtype), self.fill_value)
#     290 if self.mask_and_scale:
#     291     for iii, band_iii in enumerate(np.atleast_1d(band_key) - 1):
#
# File ~\Anaconda3\envs\CRS\lib\site-packages\numpy\ma\core.py:628, in filled(a, fill_value)
#     583 """
#     584 Return input as an array with masked data replaced by a fill value.
#     585
#    (...)
#     625
#     626 """
#     627 if hasattr(a, 'filled'):
# --> 628     return a.filled(fill_value)
#     630 elif isinstance(a, ndarray):
#     631     # Should we check for contiguity ? and a.flags['CONTIGUOUS']:
#     632     return a
#
# File ~\Anaconda3\envs\CRS\lib\site-packages\numpy\ma\core.py:3794, in MaskedArray.filled(self, fill_value)
#    3792     return self._data
#    3793 else:
# -> 3794     result = self._data.copy('K')
#    3795     try:
#    3796         np.copyto(result, fill_value, where=m)
#
# MemoryError: Unable to allocate 2.85 GiB for an array with shape (1, 26230, 29150) and data type float32

# %%
fn = dem_path+r['name']+'_2022_04_04.nc'
dsa.to_netcdf(fn)
# Out:
# 0 C:/crs/proj/2021_FloSupp_Release/clipfest/dems/20190830_Ocracoke_Inlet_to_Ophelia_Inlet_NAD83_2011_NAVD88_UTM18_1m_adj_cog.tif
# (26230,) (29150,) (1, 26230, 29150)
# (29150,) (26230,) (26230, 29150)
# 1 C:/crs/proj/2021_FloSupp_Release/clipfest/dems/20190912-13_Ocracoke_Inlet_to_Ophelia_Inlet_NAD83_2011_NAVD88_UTM18_1m_adj_cog.tif

# %%
# %%time
# Read in the fill map and make netcdf files
fill_dir = "C:/crs/proj/2019_DorianOBX/Santa_Cruz_Products/merged_dems/"

fn = fill_dir+fill_fnames
print(fn)

daf = rioxarray.open_rasterio( fn, masked=True )


print( np.shape(np.flipud(daf['y'].values)), np.shape(daf['x'].values), np.shape( np.flipud(daf.values)) )
x = daf['x'].values
y = np.flipud(daf['y'].values)

# Not sure how da.values got a singleton dimension, but squeeze gets rid of it.
# However, make sure to squeeze before flipping
z = np.flipud(np.squeeze(daf.values))
print(np.shape(x),np.shape(y),np.shape(z))

f = interpolate.RegularGridInterpolator( (y, x), z, method='nearest')   

# Array for interpolated elevations
zi=np.NaN*np.ones((ny,nx))

# this is a slow iteration through all of the points, but allows us to skip ones that are outside
# for ij in np.ndindex(zi.shape):
#     try:
#         zi[ij]=f((yu[ij],xu[ij]))
#     except:
#         zi[ij]=np.NaN

# this is the fast technique.
zi=f((yu,xu))

da = xr.DataArray(zi,dims=['Alongshore','Cross-shore'],coords={'Alongshore': ycoords, 'Cross-shore':xcoords })
da = da.chunk()

fno = dem_path+r['name']+'_Sep_fill.nc'
da.to_netcdf(fno)
